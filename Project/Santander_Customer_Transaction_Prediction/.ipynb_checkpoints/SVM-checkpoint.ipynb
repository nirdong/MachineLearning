# %%
from libsvm.svmutil import *
from libsvm.svm import *

# %%
#Import Library
from sklearn import svm


import pandas as pd
train = pd.read_csv('/Users/Moli/Documents/InputML/santander-customer-transaction-prediction/train.csv')
test = pd.read_csv('/Users/Moli/Documents/InputML/santander-customer-transaction-prediction/test.csv')
print("Train: ",train.shape)
print("Test: ", test.shape)
# Out:
# Train:  (200000, 202)
# Test:  (200000, 201)

# %%
print("Train: ",train.shape)
# Out:
# Train:  (200000, 202)

# %%
#target = train.pop('target')
train_ids = train.pop('ID_code')
test_ids = test.pop('ID_code')
len_train = len(train)

# %%
from sklearn.model_selection import train_test_split
train_X, val_X, train_y, val_y = train_test_split(train, target, random_state = 0)

# %%
import pandas as pd 
import time
def df2ffm(df, fp):
        '''
        Convert pandas.DataFrame to data format that libffm can directly use


        @Args:
            df: pandas.DataFrame to be converted
            fp: save libffm format data to fp<filepath>
        '''
        now = time.time()
        print('Format Converting begin in time:...',now)
        columns = df.columns.values
        d = len(columns)
        feature_index = [i for i in range(d)]
        field_index = [0]*d
        field = []
        for col in columns:
            field.append(col.split('_')[0])
        index = -1
        for i in range(d):
            if i==0 or field[i]!=field[i-1]:
                index+=1
            field_index[i] = index


        with open(fp, 'w') as f:
            for row in df.values:
                line =str(int(row[0]))
                #print(line)
                for i in range(1, len(row)):
                    if row[i]!=0:
                        line += " %d:%.4f" % (feature_index[i], row[i])
                       # print(line)
                line+='\n'
                f.write(line)
        print('finish convert,the cost time is ',time.time()-now)
        print('[Done]')
        print()

def main():
    df = train_X
    df = df.fillna(0) 
    fp = '/Users/Moli/Documents/InputML/santander-customer-transaction-prediction/train_libsvm.txt' 
    df2ffm(df,fp)


if __name__ == '__main__':
    main()
# Out:
# Format Converting begin in time:... 1552492139.539655
# finish convert,the cost time is  66.0397081375122
# [Done]

# %%
y_train, x_train = svm_read_problem('/Users/Moli/Documents/InputML/santander-customer-transaction-prediction/train_libsvm.txt')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-6aa73aa49e61> in <module>()
# ----> 1 y_t, x_t = svm_read_problem('/Users/Moli/Documents/InputML/santander-customer-transaction-prediction/train_libsvm.txt')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/libsvm/commonutil.py in svm_read_problem(data_file_name, return_scipy)
#      46                         for e in features.split():
#      47                                 ind, val = e.split(":")
# ---> 48                                 xi[int(ind)] = float(val)
#      49                         prob_x += [xi]
#      50         if scipy != None and return_scipy:
#
# KeyboardInterrupt:

# %%
x[0]
# Out:
# {1: 7.171,
#  2: 0.078,
#  3: 9.7313,
#  4: 5.2754,
#  5: 8.4569,
#  6: 1.0961,
#  7: 5.6193,
#  8: 19.7863,
#  9: -3.0315,
#  10: 6.8223,
#  11: 2.5263,
#  12: 4.9981,
#  13: 13.9677,
#  14: 6.8061,
#  15: 4.7322,
#  16: 14.1186,
#  17: 9.0974,
#  18: -11.224,
#  19: 17.9139,
#  20: 11.0509,
#  21: 14.7752,
#  22: 32.8374,
#  23: 10.2966,
#  24: 3.4888,
#  25: 6.2547,
#  26: 13.5648,
#  27: -5.7459,
#  28: -0.6498,
#  29: 4.3383,
#  30: 4.7462,
#  31: -13.1613,
#  32: 10.5528,
#  33: -0.7888,
#  34: 11.6772,
#  35: 11.2966,
#  36: 7.9723,
#  37: 5.8383,
#  38: 8.446,
#  39: 13.3923,
#  40: -4.493,
#  41: -3.6582,
#  42: 21.8811,
#  43: 11.053,
#  44: 11.1239,
#  45: 7.0044,
#  46: 22.6236,
#  47: 12.6362,
#  48: 2.1626,
#  49: 12.338,
#  50: 0.3947,
#  51: 12.8739,
#  52: 1.9467,
#  53: 0.8782,
#  54: 6.4447,
#  55: 0.9115,
#  56: 4.2942,
#  57: 13.2052,
#  58: 7.0352,
#  59: 1.306,
#  60: 8.4459,
#  61: 11.4387,
#  62: -2.4532,
#  63: 1.3004,
#  64: 1.6206,
#  65: 5.1474,
#  66: 4.9615,
#  67: 7.5834,
#  68: 14.9247,
#  69: 5.0257,
#  70: 4.1512,
#  71: 9.9754,
#  72: 0.2604,
#  73: -1.8798,
#  74: 36.3693,
#  75: 7.7765,
#  76: 20.1144,
#  77: 1.4912,
#  78: 20.0586,
#  79: 2.841,
#  80: 13.1776,
#  81: 8.6265,
#  82: 12.7536,
#  83: -1.719,
#  84: 12.8373,
#  85: -8.6998,
#  86: 13.8136,
#  87: 9.6532,
#  88: 18.5427,
#  89: 6.756,
#  90: 0.1817,
#  91: -2.9251,
#  92: 7.0631,
#  93: 13.8521,
#  94: 11.2532,
#  95: 14.1587,
#  96: 1.4554,
#  97: 2.3744,
#  98: -2.3263,
#  99: 2.6067,
#  100: 1.0724,
#  101: 6.3788,
#  102: 11.6789,
#  103: 25.5324,
#  104: 1.3462,
#  105: 7.2301,
#  106: 3.5881,
#  107: 8.1421,
#  108: 24.0525,
#  109: 14.4737,
#  110: 21.8837,
#  111: 5.7288,
#  112: 6.424,
#  113: 3.2995,
#  114: 13.6222,
#  115: 3.9122,
#  116: 1.5824,
#  117: 2.2756,
#  118: 34.2242,
#  119: 11.0703,
#  120: 1.5267,
#  121: 26.4063,
#  122: 13.1856,
#  123: 2.965,
#  124: 2.2056,
#  125: 4.2155,
#  126: 12.8844,
#  127: 12.2297,
#  128: -1.3604,
#  129: 2.7546,
#  130: 19.357,
#  131: 11.5218,
#  132: 0.9336,
#  133: 7.4662,
#  134: 6.1763,
#  135: -3.825,
#  136: 3.9852,
#  137: 12.1453,
#  138: 22.6057,
#  139: -5.8843,
#  140: -6.227,
#  141: 8.7105,
#  142: 2.9077,
#  143: 9.5127,
#  144: 8.5254,
#  145: 8.8973,
#  146: -1.8792,
#  147: 8.3983,
#  148: 5.6177,
#  149: 4.2395,
#  150: 23.9701,
#  151: 17.6876,
#  152: 11.1159,
#  153: 7.9044,
#  154: 16.0167,
#  155: 3.4464,
#  156: -7.9319,
#  157: 12.4025,
#  158: -14.8599,
#  159: 12.3975,
#  160: 14.0652,
#  161: 30.498,
#  162: 5.7451,
#  163: 4.6325,
#  164: 5.0144,
#  165: 1.4196,
#  166: 23.7389,
#  167: 2.675,
#  168: -1.3684,
#  169: 7.6428,
#  170: 5.7646,
#  171: -3.8745,
#  172: -10.4765,
#  173: 25.1012,
#  174: -9.9958,
#  175: 27.2812,
#  176: 6.2933,
#  177: -15.8091,
#  178: 10.4539,
#  179: -9.3122,
#  180: 2.8948,
#  181: -4.821,
#  182: 8.408,
#  183: 5.0552,
#  184: 16.9429,
#  185: 14.0333,
#  186: 2.5933,
#  187: 12.6163,
#  188: -7.2145,
#  189: 12.9924,
#  190: 1.2416,
#  191: 1.3701,
#  192: 9.9152,
#  193: 2.0668,
#  194: 5.3564,
#  195: 21.6815,
#  196: -0.1577,
#  197: -1.3003,
#  198: 8.4862,
#  199: 16.8159,
#  200: -7.3853}

# %%
train_X.head()
# Out:
#           var_0   var_1    var_2   var_3    var_4    var_5   var_6    var_7  \
# 105800   7.1710  0.0780   9.7313  5.2754   8.4569   1.0961  5.6193  19.7863
# 27538   12.9988 -0.8167   9.0578  6.1068   9.0826 -20.3450  7.3668  20.5931
# 108979  11.2861 -0.2255  17.2522  5.8849  13.0078   4.0183  5.0971  11.4301
# 184818  13.4434 -5.7222  13.4512  4.7605  14.5425   2.6660  5.8011  19.3957
# 121763   7.3488  3.2396  12.8417  8.3421  12.0869  -0.3122  4.1239  11.7267
#
#          var_8   var_9   ...     var_190  var_191  var_192  var_193  var_194  \
# 105800 -3.0315  6.8223   ...      1.3701   9.9152   2.0668   5.3564  21.6815
# 27538   4.4952  8.3794   ...      2.2635   9.9614   0.9975   4.2109  19.2522
# 108979 -1.7817  6.3523   ...      7.1895  11.7965   2.2497  10.9765  18.8830
# 184818  1.4480  7.6016   ...     -2.5342   6.7572   4.1626   1.5798  18.3637
# 121763  0.8601  9.4517   ...      6.8424   3.1530   2.0189   3.3557  22.6439
#
#         var_195  var_196  var_197  var_198  var_199
# 105800  -0.1577  -1.3003   8.4862  16.8159  -7.3853
# 27538   -0.2888   2.2767   8.4979  13.6564  -1.1474
# 108979   1.0117   1.8379   7.3530  13.5594   6.4416
# 184818   1.7772   9.0057   8.5145  18.6113   3.9470
# 121763   0.2648   0.3030   8.0920  16.3242 -10.1387
#
# [5 rows x 200 columns]

# %%
from sklearn.model_selection import train_test_split
train_X, val_X, train_y, val_y = train_test_split(train, target, random_state = 0)

# %%
model = svm_train(train_X, train_y)
 
p_label, p_acc, p_val = svm_predict(val_X, val_y, model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-e5f8cc35171d> in <module>()
# ----> 1 model = svm_train(train_X, train_y)
#       2
#       3 p_label, p_acc, p_val = svm_predict(val_X, val_y, model)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/libsvm/svmutil.py in svm_train(arg1, arg2, arg3)
#      98                         param = svm_parameter(arg2)
#      99         if prob == None or param == None:
# --> 100                 raise TypeError("Wrong types for the arguments")
#     101
#     102         if param.kernel_type == PRECOMPUTED:
#
# TypeError: Wrong types for the arguments

# %%
model = svm.SVC(kernel='linear', C=1, gamma=1) 
# there is various option associated with it, like changing kernel, gamma and C value. Will discuss more # about it in next section.Train the model using the training sets and check score
model.fit(train_X, train_y)
y_pred= model.predict(val_X)

# %%
from sklearn.metrics import roc_auc_score
auc_score1 = roc_auc_score(val_y, y_pred)
